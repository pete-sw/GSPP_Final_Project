# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, matplotlib.font_manager as fm
from shapely.geometry import Polygon, Point
from geopy.distance import great_circle
from geopandas import GeoDataFrame
from descartes import PolygonPatch
 
#df = pd.read_csv('../Data/Initial_DC_Locations.csv', encoding='utf-8')
rs = pd.read_csv('../Data/Initial_DC_Locations.csv', encoding='utf-8')
all_countries = GeoDataFrame.from_file('../Data/state_energy.shp')

# %%
title_font = fm.FontProperties(family='Bitstream Vera Sans', style='normal', size=15, weight='normal', stretch='normal')
annotation_font = fm.FontProperties(family='Bitstream Vera Sans', style='normal', size=10, weight='normal', stretch='normal')
backgroundcolor = '#e4f4ff'

# %%
#Working on the projection
original_crs = all_countries.crs
target_crs = {'datum':'WGS84', 'no_defs':True, 'proj':'aea', 'lat_1':24, 'lat_2':49, 'lat_0':-125, 'lon_0':-67}
all_countries.to_crs(crs=target_crs, inplace=True)

# %%
all_countries.head()
# Out:
#    DRAWSEQ STATE_ABBR STATE_FIPS    STATE_NAME          SUB_REGION  \
# 0        2         WA         53    Washington             Pacific
# 1        3         MT         30       Montana            Mountain
# 2        4         ME         23         Maine         New England
# 3        5         ND         38  North Dakota  West North Central
# 4        6         SD         46  South Dakota  West North Central
#
#                                             geometry state_en_1 state_en_2  \
# 0  (POLYGON ((-3890014.170202594 10300826.7121903...         77          8
# 1  POLYGON ((-3355141.097712231 9552716.912360113...         42          6
# 2  (POLYGON ((-218751.7007568304 8715380.47899398...         61         32
# 3  POLYGON ((-2390236.272277357 9310272.848563397...         21         16
# 4  POLYGON ((-2801098.248247745 9104084.67547209,...         65         26
#
#   state_en_3 state_en_4 state_en_5 state_en_6 state_en_7 state_en_8 state_ener
# 0      86658       8751     113321    47.3917  -121.5708       4.54         WA
# 1      11614       1661      27573    46.9048  -110.3261       5.44         MT
# 2       8554       4509      14079    44.6074   -69.3977       7.44         ME
# 3       7387       5535      35361    47.5362    -99.793       8.11         ND
# 4       6765       2688      10358    44.2853   -99.4632       7.11         SD

# %%
rs['geometry'] = None
for i, row in rs.iterrows():
    rs['geometry'][i] = Point(row['lon'], row['lat'])
points = GeoDataFrame(rs)
#Ummm changed from original to target because with original it said latitude or longitude exceeded limits
points.crs = target_crs
# Out:
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
points.to_crs(crs=target_crs, inplace=True)
points['x'] = None
points['y'] = None
for i, row in points.iterrows():
    points['x'][i] = row['geometry'].x
    points['y'][i] = row['geometry'].y
# Out:
# -c:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x_margin_width = (points.bounds['maxx'].max() - points.bounds['minx'].min()) / 10
y_margin_width = (points.bounds['maxy'].max() - points.bounds['miny'].min()) / 3
 
xlim = (points.bounds['minx'].min() - x_margin_width, points.bounds['maxx'].max() + x_margin_width)
ylim = (points.bounds['miny'].min() - y_margin_width, points.bounds['maxy'].max() + y_margin_width)
 
xdim = (xlim[1] - xlim[0]) / 400000
ydim = (ylim[1] - ylim[0]) / 400000

# %%
spatial_extent = Polygon([(xlim[0], ylim[0]),
                       (xlim[0], ylim[1]),
                       (xlim[1], ylim[1]),
                       (xlim[1], ylim[0])])
countries = all_countries[all_countries['geometry'].intersects(spatial_extent)]

# %%
def get_patches(countries, visited_countries):
 
    facecolor = '#f7f7f7'
    visited_facecolor = '#eeeeee'
    edgecolor = '#cccccc'
    patches = []
 
    for i, row in countries.iterrows():
        if type(row['geometry']) == Polygon:
            fc = visited_facecolor if row['STATE_NAME'] in visited_countries else facecolor
            patch = PolygonPatch(row['geometry'], fc=fc, ec=edgecolor, zorder=0)
            patches.append(patch)
        else:
            for polygon in row['geometry']:
                fc = visited_facecolor if row['STATE_NAME'] in visited_countries else facecolor
                patch = PolygonPatch(polygon, fc=fc, ec=edgecolor, zorder=0)
                patches.append(patch)
    return patches

# %%
most_index = df['State'].value_counts().index
most = pd.DataFrame(points[points['State'].isin(most_index)])
most.drop_duplicates(subset=['State'], take_last=False, inplace=True)

# %%
visited_countries = rs['State'].unique()
#countries = countries.replace('The former Yugoslav Republic of Macedonia', 'Macedonia (FYROM)')

# %%
fig = plt.figure(figsize=(xdim, ydim))
ax = fig.add_subplot(111)
ax.set_axis_bgcolor(backgroundcolor)
 
for patch in get_patches(countries, visited_countries):
    ax.add_patch(patch)
#points_scatter = ax.scatter(x=points['x'], y=points['y'], c='m', alpha=0.4, s=100)
 
ax.set_title('Projected shapefile and GPS coordinates', fontproperties=title_font)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_xticks([])
ax.set_yticks([])
 
# for i, row in most.iterrows():
#     plt.annotate(row['State'],
#                  xy=(row['x'], row['y']),
#                  xytext=(row['x'] + 35000, row['y'] - 100000),
#                  bbox=dict(boxstyle='round', color='k', fc='w', alpha=0.8),
#                  xycoords='data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in motion_notify_event(self, x, y, guiEvent)
#    1916         s = 'motion_notify_event'
#    1917         event = MouseEvent(s, self, x, y, self._button, self._key,
# -> 1918                            guiEvent=guiEvent)
#    1919         self.callbacks.process(s, event)
#    1920
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, button, key, step, dblclick, guiEvent)
#    1508         button pressed None, 1, 2, 3, 'up', 'down'
#    1509         """
# -> 1510         LocationEvent.__init__(self, name, canvas, x, y, guiEvent=guiEvent)
#    1511         self.button = button
#    1512         self.key = key
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in __init__(self, name, canvas, x, y, guiEvent)
#    1410         if self.canvas.mouse_grabber is None:
#    1411             axes_list = [a for a in self.canvas.figure.get_axes()
# -> 1412                          if a.in_axes(self)]
#    1413         else:
#    1414             axes_list = [self.canvas.mouse_grabber]
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in in_axes(self, mouseevent)
#    1714         is in the Axes
#    1715         """
# -> 1716         return self.patch.contains(mouseevent)[0]
#    1717
#    1718     def get_autoscale_on(self):
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in contains(self, mouseevent)
#     632             return False, {}
#     633
# --> 634         x, y = self.get_transform().inverted().transform_point(
#     635             (mouseevent.x, mouseevent.y))
#     636         return (x >= 0.0 and x <= 1.0 and y >= 0.0 and y <= 1.0), {}
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2281
#    2282     def inverted(self):
# -> 2283         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2284     inverted.__doc__ = Transform.inverted.__doc__
#    2285
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1686             if self._shorthand_name:
#    1687                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1688             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1689             self._invalid = 0
#    1690         return self._inverted
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     518     signature = 'D->D' if isComplexType(t) else 'd->d'
#     519     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 520     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     521     return wrap(ainv.astype(result_t))
#     522
#
# /Users/Peter_Swigert/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
# %pylab inline

import shapefile
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

import numpy as np

#   -- input --
sf = shapefile.Reader("../Data/state_energy")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = np.array(cns)
#cm    = get_cmap('Dark2')
#cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure()
ax      = fig.add_subplot(111)

colors = ["red", "green"]

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = np.array(shapes[nshp].points)
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    ax.add_collection(PatchCollection(ptchs,facecolor=colors, edgecolor='k', linewidths=.1))
ax.set_xlim(-140,-40)
ax.set_ylim(20,50)
